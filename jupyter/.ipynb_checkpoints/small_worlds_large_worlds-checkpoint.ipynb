# %% [markdown]
# # Small Worlds and Large Worlds
# An Introduction to Bayesian Inference
#
# Exercise 2M1 Grid Approximations of various observations of either W (water) or L (land)

# %%
library(ggplot2)

# define init grid
p_grid <- seq(from=0, to=1, length.out=20)

# define prior
prior <- rep(1, 20) # uniform

# %% [markdown]
# Observation: W,W,W

# %%
# compute likelihood at each value in grid
likelihood <- dbinom(3, size=3, prob=p_grid)

# compute product of likelihood posterior
unstd.posterior <- likelihood * prior

# standardize the posterior so it sums up to 1
posterior <- unstd.posterior / sum(unstd.posterior)

ggplot(data.frame(prob=p_grid,
                  post=posterior),
      aes(x=prob, y=posterior)) +
geom_point() + geom_line() + theme_bw() +
labs(x="Probability of Water", y="Posterior Probability")
# Out:
# plot without title

# %% [markdown]
# Observation: W,W,W,L

# %%
# compute likelihood at each value in grid
likelihood <- dbinom(3, size=4, prob=p_grid)

# compute product of likelihood posterior
unstd.posterior <- likelihood * prior

# standardize the posterior so it sums up to 1
posterior <- unstd.posterior / sum(unstd.posterior)

ggplot(data.frame(prob=p_grid,
                  post=posterior),
      aes(x=prob, y=posterior)) +
geom_point() + geom_line() + theme_bw() +
labs(x="Probability of Water", y="Posterior Probability")
# Out:
# plot without title

# %% [markdown]
# Observation: L,W,W,L,W,W,W

# %%
# compute likelihood at each value in grid
likelihood <- dbinom(5, size=7, prob=p_grid)

# compute product of likelihood posterior
unstd.posterior <- likelihood * prior

# standardize the posterior so it sums up to 1
posterior <- unstd.posterior / sum(unstd.posterior)

ggplot(data.frame(prob=p_grid,
                  post=posterior),
      aes(x=prob, y=posterior)) +
geom_point() + geom_line() + theme_bw() +
labs(x="Probability of Water", y="Posterior Probability")
# Out:
# plot without title

# %% [markdown]
# Exercise 2M2: Adjust prior to be 0 when p < 0.5 and a postive constant when p > 0.5

# %%
prior_new <- prior

prior_new[p_grid < 0.5] <- 0

# %% [markdown]
# Redo all previous estimates

# %%
# compute likelihood at each value in grid
likelihood <- dbinom(3, size=3, prob=p_grid)

# compute product of likelihood posterior
unstd.posterior <- likelihood * prior_new

# standardize the posterior so it sums up to 1
posterior <- unstd.posterior / sum(unstd.posterior)

ggplot(data.frame(prob=p_grid,
                  post=posterior),
      aes(x=prob, y=posterior)) +
geom_point() + geom_line() + theme_bw() +
labs(x="Probability of Water", y="Posterior Probability")
# Out:
# plot without title

# %%
# compute likelihood at each value in grid
likelihood <- dbinom(3, size=4, prob=p_grid)

# compute product of likelihood posterior
unstd.posterior <- likelihood * prior_new

# standardize the posterior so it sums up to 1
posterior <- unstd.posterior / sum(unstd.posterior)

ggplot(data.frame(prob=p_grid,
                  post=posterior),
      aes(x=prob, y=posterior)) +
geom_point() + geom_line() + theme_bw() +
labs(x="Probability of Water", y="Posterior Probability")
# Out:
# plot without title

# %%
# compute likelihood at each value in grid
likelihood <- dbinom(5, size=7, prob=p_grid)

# compute product of likelihood posterior
unstd.posterior <- likelihood * prior_new

# standardize the posterior so it sums up to 1
posterior <- unstd.posterior / sum(unstd.posterior)

ggplot(data.frame(prob=p_grid,
                  post=posterior),
      aes(x=prob, y=posterior)) +
geom_point() + geom_line() + theme_bw() +
labs(x="Probability of Water", y="Posterior Probability")
# Out:
# plot without title
