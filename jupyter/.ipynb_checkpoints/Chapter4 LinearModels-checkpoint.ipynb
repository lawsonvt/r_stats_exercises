# %% [markdown]
# ## Examples in 4.1

# %%
library(rethinking)
# Out:
# Loading required package: rstan
# Loading required package: ggplot2
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Loading required package: StanHeaders
# rstan (Version 2.18.2, GitRev: 2e1f913d3ca3)
# For execution on a local, multicore CPU with excess RAM we recommend calling
# options(mc.cores = parallel::detectCores()).
# To avoid recompilation of unchanged Stan programs, we recommend calling
# rstan_options(auto_write = TRUE)
# Loading required package: parallel
# rethinking (Version 1.59)

# %%
growth <- replicate( 10000 , prod( 1 + runif(12,0,0.1) ) )
dens( growth , norm.comp=TRUE )
# Out:
# Plot with title “”

# %%
big <- replicate( 10000 , prod( 1 + runif(12,0,0.5) ) )
small <- replicate( 10000 , prod( 1 + runif(12,0,0.01) ) )

dens(big, norm.comp = T)
dens(small, norm.comp = T)
# Out:
# Plot with title “”
# Plot with title “”

# %%
# but wait, there's more!
log.big <- replicate( 10000 , log(prod(1 + runif(12,0,0.5))) )

dens(log.big, norm.comp=T)
# Out:
# Plot with title “”

# %% [markdown]
# ## Examples in 4.2

# %%
w <- 6; n <- 9;
p_grid <- seq(from=0,to=1,length.out=100)
posterior <- dbinom(w,n,p_grid)*dunif(p_grid,0,1)
posterior <- posterior/sum(posterior)

ggplot(data.frame(prob=p_grid,
                  post=posterior),
      aes(x=prob, y=posterior)) +
geom_point() + geom_line() + theme_bw()
# Out:
# plot without title

# %% [markdown]
# ## Examples in 4.3

# %% [markdown]
# ### 4.3.1

# %%
data(Howell1)
d <- Howell1

str(d)
# Out:
# 'data.frame':	544 obs. of  4 variables:
#  $ height: num  152 140 137 157 145 ...
#  $ weight: num  47.8 36.5 31.9 53 41.3 ...
#  $ age   : num  63 63 65 41 51 35 32 27 19 54 ...
#  $ male  : int  1 0 0 1 0 1 0 1 0 1 ...

# %%
d2 <- d[ d$age >= 18 , ]
nrow(d2)
# Out:
# [1] 352

# %%
dens(d2$height)
# Out:
# Plot with title “”

# %% [markdown]
# ### 4.3.2

# %%
 curve( dnorm( x , 178 , 20 ) , from=100 , to=250 )
# Out:
# plot without title

# %%
 curve( dunif( x , 0 , 50 ) , from=-10 , to=60 )
# Out:
# plot without title

# %%
sample_mu <- rnorm( 1e4 , 178 , 20 )
sample_sigma <- runif( 1e4 , 0 , 50 )
prior_h <- rnorm( 1e4 , sample_mu , sample_sigma )
dens( prior_h )
# Out:
# Plot with title “”

# %% [markdown]
# ### 4.3.3

# %%
mu.list <- seq( from=140, to=160 , length.out=200 )
sigma.list <- seq( from=4 , to=9 , length.out=200 )
post <- expand.grid( mu=mu.list , sigma=sigma.list )
post$LL <- sapply( 1:nrow(post) , function(i) sum( dnorm(
                d2$height ,
                mean=post$mu[i] ,
                sd=post$sigma[i] ,
                log=TRUE ) ) )
post$prod <- post$LL + dnorm( post$mu , 178 , 20 , TRUE ) +
    dunif( post$sigma , 0 , 50 , TRUE )
post$prob <- exp( post$prod - max(post$prod) )

# %%
contour_xyz( post$mu , post$sigma , post$prob )
# Out:
# plot without title

# %%
 image_xyz( post$mu , post$sigma , post$prob )
# Out:
# plot without title

# %% [markdown]
# ### 4.3.4

# %%
sample.rows <- sample( 1:nrow(post) , size=1e4 , replace=TRUE ,
    prob=post$prob )
sample.mu <- post$mu[ sample.rows ]
sample.sigma <- post$sigma[ sample.rows ]

# %%
  plot( sample.mu , sample.sigma , cex=0.5 , pch=16 , col=col.alpha(rangi2,0.1) )
# Out:
# plot without title

# %%
dens( sample.mu )
dens( sample.sigma )
# Out:
# Plot with title “”
# Plot with title “”

# %%
HPDI( sample.mu )
HPDI( sample.sigma )
# Out:
#    |0.89    0.89|
# 153.8693 155.1759
#    |0.89    0.89|
# 7.266332 8.195980

# %%
 d3 <- sample( d2$height , size=20 )
d3
# Out:
#  [1] 160.0200 161.9250 149.8600 147.3200 168.2750 152.4000 161.9250 153.6700
#  [9] 158.1150 160.6550 145.4150 163.8300 142.2400 148.2852 157.4800 156.2100
# [17] 160.9852 165.1000 149.8600 154.9400

# %%
mu.list <- seq( from=150, to=170 , length.out=200 )
sigma.list <- seq( from=4 , to=20 , length.out=200 )
post2 <- expand.grid( mu=mu.list , sigma=sigma.list )
post2$LL <- sapply( 1:nrow(post2) , function(i)
    sum( dnorm( d3 , mean=post2$mu[i] , sd=post2$sigma[i] ,
    log=TRUE ) ) )
post2$prod <- post2$LL + dnorm( post2$mu , 178 , 20 , TRUE ) +
    dunif( post2$sigma , 0 , 50 , TRUE )
post2$prob <- exp( post2$prod - max(post2$prod) )
sample2.rows <- sample( 1:nrow(post2) , size=1e4 , replace=TRUE ,
    prob=post2$prob )
sample2.mu <- post2$mu[ sample2.rows ]
sample2.sigma <- post2$sigma[ sample2.rows ]
plot( sample2.mu , sample2.sigma , cex=0.5 ,
    col=col.alpha(rangi2,0.1) ,
    xlab="mu" , ylab="sigma" , pch=16 )
# Out:
# plot without title

# %%
dens( sample2.sigma , norm.comp=TRUE )
# Out:
# Plot with title “”

# %% [markdown]
# ### 4.3.5

# %%
library(rethinking)
data(Howell1)
d <- Howell1
d2 <- d[ d$age >= 18 , ]

# %%
flist <- alist(
    height ~ dnorm( mu , sigma ) ,
    mu ~ dnorm( 178 , 20 ) ,
    sigma ~ dunif( 0 , 50 )
)
flist
# Out:
# [[1]]
# height ~ dnorm(mu, sigma)
#
# [[2]]
# mu ~ dnorm(178, 20)
#
# [[3]]
# sigma ~ dunif(0, 50)

# %%
 m4.1 <- map( flist , data=d2 )

# %%
 precis( m4.1 )
# Out:
#         Mean StdDev   5.5%  94.5%
# mu    154.61   0.41 153.95 155.27
# sigma   7.73   0.29   7.27   8.20

# %%
m4.2 <- map(
        alist(
            height ~ dnorm( mu , sigma ) ,
            mu ~ dnorm( 178 , 0.1 ) ,
            sigma ~ dunif( 0 , 50 )
),
        data=d2 )
precis( m4.2 )
# Out:
#         Mean StdDev   5.5%  94.5%
# mu    177.86   0.10 177.70 178.02
# sigma  24.52   0.93  23.03  26.00

# %% [markdown]
# ### 4.3.6

# %%
 vcov( m4.1 )
# Out:
#       mu           sigma
# mu    0.1697396109 0.0002180336
# sigma 0.0002180336 0.0849058220

# %%
diag( vcov( m4.1 ) )
cov2cor( vcov( m4.1 ) )
# Out:
#         mu      sigma
# 0.16973961 0.08490582
#       mu          sigma
# mu    1.000000000 0.001816198
# sigma 0.001816198 1.000000000

# %%
post <- extract.samples( m4.1 , n=1e4 )
head(post)
# Out:
#   mu       sigma
# 1 154.1371 7.282860
# 2 154.7981 7.949628
# 3 154.8507 7.340517
# 4 153.9761 7.246567
# 5 154.3740 7.930611
# 6 155.0893 7.398799

# %%
precis(post)
# Out:
#         Mean StdDev  |0.89  0.89|
# mu    154.61   0.41 153.95 155.27
# sigma   7.73   0.30   7.27   8.21
